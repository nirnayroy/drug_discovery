# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %%
import pandas as pd  
   
# list of name, degree, score 
nme = ["aparna", "pankaj", "sudhir", "Geeku"] 
deg = ["MBA", "BCA", "M.Tech", "MBA"] 
scr = [90, 40, 80, 98] 
   
# dictionary of lists  
dict = {'name': nme, 'degree': deg, 'score': scr}  
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv(r'./data/file3.csv', index=False)

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl-webresource-client-0.10.2.tar.gz (51 kB)
# Collecting urllib3
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 425, in _error_catcher
#     yield
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 507, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\http\client.py", line 457, in read
#     n = self.readinto(b)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\http\client.py", line 501, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\commands\install.py", line 331, in run
#     resolver.resolve(requirement_set)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\legacy_resolve.py", line 177, in resolve
#     discovered_reqs.extend(self._resolve_one(requirement_set, req))
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\legacy_resolve.py", line 333, in _resolve_one
#     abstract_dist = self._get_abstract_dist_for(req_to_install)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\legacy_resolve.py", line 282, in _get_abstract_dist_for
#     abstract_dist = self.preparer.prepare_linked_requirement(req)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\operations\prepare.py", line 482, in prepare_linked_requirement
#     hashes=hashes,
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\operations\prepare.py", line 287, in unpack_url
#     hashes=hashes,
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\operations\prepare.py", line 159, in unpack_http_url
#     link, downloader, temp_dir.path, hashes
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\operations\prepare.py", line 303, in _download_http_url
#     for chunk in download.chunks:
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\utils\ui.py", line 160, in iter
#     for x in it:
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_internal\network\utils.py", line 39, in response_chunks
#     decode_content=False,
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 564, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 529, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\Nirnay\Anaconda3\envs\myenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 430, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   14.0
# 2                                 Feline coronavirus   14.0
# 3                             Human coronavirus 229E   13.0
# 4                SARS coronavirus 3C-like proteinase   10.0
# 5  Middle East respiratory syndrome-related coron...    9.0
# 6                          Replicase polyprotein 1ab    5.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False     CHEMBL613837
# 4               False       CHEMBL3927
# 5               False    CHEMBL4296578
# 6               False       CHEMBL5118
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM    11137
# 4  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 5                                                 []        ORGANISM  1335626
# 6  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1480935                  []    CHEMBL829584
# 1             None      1480936                  []    CHEMBL829584
# 2             None      1481061                  []    CHEMBL830868
#
#                                    assay_description assay_type bao_endpoint  \
# 0  In vitro inhibitory concentration against SARS...          B  BAO_0000190
# 1  In vitro inhibitory concentration against SARS...          B  BAO_0000190
# 2  In vitro inhibitory concentration against SARS...          B  BAO_0000190
#
#     bao_format              bao_label  \
# 0  BAO_0000357  single protein format
# 1  BAO_0000357  single protein format
# 2  BAO_0000357  single protein format
#
#                           canonical_smiles  ...   target_organism  \
# 0   Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21  ...  SARS coronavirus
# 1   O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21  ...  SARS coronavirus
# 2  O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21  ...  SARS coronavirus
#
#                       target_pref_name target_tax_id text_value  toid  type  \
# 0  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 1  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 2  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None   7.2
# 1    uM  UO_0000065        None   9.4
# 2    uM  UO_0000065        None  13.5
#
# [3 rows x 43 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv(r'./data/bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 43 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id  ...             0
# 0         CHEMBL187579  ...  intermediate
# 1         CHEMBL188487  ...  intermediate
# 2         CHEMBL185698  ...      inactive
# 3         CHEMBL426082  ...      inactive
# 4         CHEMBL187717  ...  intermediate
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...      inactive
# 129       CHEMBL187460  ...      inactive
# 130       CHEMBL363535  ...      inactive
# 131       CHEMBL227075  ...      inactive
# 132        CHEMBL45830  ...      inactive
#
# [133 rows x 5 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv(r'./data/bioactivity_preprocessed_data.csv', 'bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 92
# -rw-r--r-- 1 root root 70010 Apr 29 17:07 bioactivity_data.csv
# -rw-r--r-- 1 root root  9326 Apr 29 17:24 bioactivity_preprocessed_data.csv
# drwx------ 4 root root  4096 Apr 29 17:08 gdrive
# drwxr-xr-x 1 root root  4096 Apr  3 16:24 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
